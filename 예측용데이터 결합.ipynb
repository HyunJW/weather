# %%
import pandas as pd
import glob

# %%
df_addr = pd.read_csv('./관측소주소.csv', encoding='cp949')

# %%
obsevatory = df_addr['관측소명'].apply(lambda x: x.split('(')[0])

# %%
for observ in obsevatory:
    try:
        path = 'C:/Users/songh/Desktop/workspace/weather/data/'
        files = glob.glob(path + "*.xls")
        excel = pd.DataFrame()
        for file_name in files:
            df = pd.read_excel(file_name, header=5)
            df = df[df.columns[0::2]]
            df.columns = ['일시', 'PM10', 'PM2.5', 'O3', 'NO2', 'CO', 'SO2']
            excel = excel.append(df, ignore_index=True)
        excel['일시'] = excel['일시'].apply(lambda x: (x.replace(':', ' ') + ':00'))
        excel.sort_values('일시', inplace=True)
        excel['지점명'] = observ
        columns = ['지점명', '일시', 'PM10', 'PM2.5', 'O3', 'NO2', 'CO', 'SO2']
        excel = excel[columns]
        excel.to_csv(path + '예측용관측소.csv', index=False)

    except Exception as ex:
        print('error' + str(ex))
# Out:
# C:\Users\songh\AppData\Local\Temp\ipykernel_11576\1546250618.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   excel = excel.append(df, ignore_index=True)
# C:\Users\songh\AppData\Local\Temp\ipykernel_11576\1546250618.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   excel = excel.append(df, ignore_index=True)
# C:\Users\songh\AppData\Local\Temp\ipykernel_11576\1546250618.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   excel = excel.append(df, ignore_index=True)
# C:\Users\songh\AppData\Local\Temp\ipykernel_11576\1546250618.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...
