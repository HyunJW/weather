# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import time
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

# %%
url='https://data.kma.go.kr/data/grnd/selectAsosRltmList.do?pgmNo=36'
driver=webdriver.Chrome()
driver.get(url)

# %%
driver.find_element(By.ID, value='btnStn2').click()

# %%
addr=[]
for i in range(1,104):
    map_addr=driver.find_element(By.XPATH,'//*[@id="gdsMap"]/div[1]/div/div[1]/div[3]/div[2]/div[i]')
    print(map_addr.find_element(By.CLASS,value='STN_ADDR'))
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[11], line 3
#       1 addr=[]
#       2 for i in range(1,104):
# ----> 3     map_addr=driver.find_element(By.XPATH,'//*[@id="gdsMap"]/div[1]/div/div[1]/div[3]/div[2]/div[i]')
#       4     print(map_addr.find_element(By.CLASS,value='STN_ADDR'))
#
# File c:\python38\lib\site-packages\selenium\webdriver\remote\webdriver.py:830, in WebDriver.find_element(self, by, value)
#     827     by = By.CSS_SELECTOR
#     828     value = f'[name="{value}"]'
# --> 830 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File c:\python38\lib\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
# --> 440     self.error_handler.check_response(response)
# ...

# %%
driver.find_element(By.XPATH,'//*[@id="layerStnInfo"]/tbody/tr[3]/td/span')
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="d918d9fa91b19979868a485d0e4cbb5e", element="b011c551-b04a-477c-8b89-2eb940899c09")>

# %%
driver.find_element(By.ID, value='layerStnInfo')
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="d918d9fa91b19979868a485d0e4cbb5e", element="4470bd1f-ff27-423a-8e97-caefdf2e36c1")>

# %%
driver.find_element(By.XPATH,'//*[@id="gdsMap"]/div[1]/div/div[1]/div[3]/div[2]/div[1]/img').click()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[127], line 1
# ----> 1 driver.find_element_by_xpath('//*[@id="gdsMap"]/div[1]/div/div[1]/div[3]/div[2]/div[1]/img').click()
#
# AttributeError: 'WebDriver' object has no attribute 'find_element_by_xpath'

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')
soup
# Out:
# <html dir="ltr" lang="ko-KR"><head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>기상자료개방포털[데이터:기상관측:지상:종관기상관측(ASOS):자료]</title>
# <meta content="기상청, 기상자료개방포털" name="keywords"/>
# <meta content="기상청, 기상자료개방포털" name="description"/>
# <meta content="width=device-width" name="viewport"/><!-- , initial-scale=0.5, minimum-scale=0.5, maximum-scale=1.0 -->
# <link href="/resources/images/favicon.png" rel="shortcut icon"/>
# <link href="/resources/css/common.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/resources/css/font-awesome.min.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/resources/css/common-ui.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/resources/css/board.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="/resources/css/layout.css" media="all" rel="stylesheet" type="text/css"/>
# ...

# %%
lis = soup.select('div.wrap_map div#gdsMap > div > div > div > div > div')

# %%
lis[3]
# Out:
# <div style="overflow: visible; width: 100%; height: 0px; position: absolute; margin: 0px; padding: 0px; border: 0px none; top: 0px; left: 0px; z-index: 103;"><div style="position: absolute; overflow: hidden; box-sizing: content-box !important; cursor: inherit; left: 503px; top: 150px; width: 28px; height: 37px;" title="강릉(105)|강원도 강릉시 용강동 63-20|10월 3, 1911|12월 31, 2100|강원도_162_105_강릉|0|Y"><img alt="" draggable="false" src="/resources/images/common/pin_spot.png" style="margin: 0px; padding: 0px; border: 0px solid transparent; display: block; user-select: none; -webkit-user-drag: none; box-sizing: content-box !important; max-width: none !important; max-height: none !important; min-width: 0px !important; min-height: 0px !important; position: absolute; cursor: pointer; width: 28px; height: 37px; left: 0px; top: 0px;" unselectable="on"/></div><div style="position: absolute; overflow: hidden; box-sizing: content-box !important; cursor: inherit; left: 120px; top: 852px; width: 28px; height:
# ...

# %%
lis[3]
# Out:
# <div style="overflow: visible; width: 100%; height: 0px; position: absolute; margin: 0px; padding: 0px; border: 0px none; top: 0px; left: 0px; z-index: 103;"><div style="position: absolute; overflow: hidden; box-sizing: content-box !important; cursor: inherit; left: 503px; top: 150px; width: 28px; height: 37px;" title="강릉(105)|강원도 강릉시 용강동 63-20|10월 3, 1911|12월 31, 2100|강원도_162_105_강릉|0|Y"><img alt="" draggable="false" src="/resources/images/common/pin_spot.png" style="margin: 0px; padding: 0px; border: 0px solid transparent; display: block; user-select: none; -webkit-user-drag: none; box-sizing: content-box !important; max-width: none !important; max-height: none !important; min-width: 0px !important; min-height: 0px !important; position: absolute; cursor: pointer; width: 28px; height: 37px; left: 0px; top: 0px;" unselectable="on"/></div><div style="position: absolute; overflow: hidden; box-sizing: content-box !important; cursor: inherit; left: 120px; top: 852px; width: 28px; height:
# ...
